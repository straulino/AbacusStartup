# %%
from abacusai import ApiClient
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv('ABACUS_API_KEY')

# %%
client = ApiClient(api_key)

# %%
projects = client.list_projects()

# %%
projects[0]
# Out:
# Project(project_id='69b4c644e',
#   name='example',
#   use_case='CHAT_LLM',
#   problem_type='CHAT_LLM',
#   created_at='2026-02-24T13:48:53+00:00')
